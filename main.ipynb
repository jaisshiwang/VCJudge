# %%
from llm.analyzer import analyze_pitch_deck
from llm.extractor import extract_text
from llm.analyzer import analyze_pitch_deck
from utils.logger import setup_logger

logger = setup_logger()

# %%
with open("data/sample_pitch_text.txt") as f:
    deck_text = f.read()

results = analyze_pitch_deck(deck_text)
print(results)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open("data/sample_pitch_text.txt") as f:
#       2     deck_text = f.read()
#       4 results = analyze_pitch_deck(deck_text)
#
# File ~/Documents/Projects/VCJudge/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/sample_pitch_text.txt'

# %%
try:
    logger.info(f"Starting analysis for: {file_path}")
    pitch_text = extract_text(file_path)
    results = analyze_pitch_deck(pitch_text)

    print("\n📊 Pitch Deck Evaluation Results\n" + "-" * 40)

    if isinstance(results, dict):
        # Print each metric with formatting
        for metric, value in results.items():
            print(f"{metric:<35}: {value}")
    else:
        # Fallback if analyzer returns a string or structured text
        print("From raw:------")
        print(results)

    logger.info("✅ Analysis completed successfully.")

except Exception as e:
    logger.critical(f"App failed: {e}", exc_info=True)
    print(f"\n❌ Error during analysis: {e}")
# Out:
# 2025-11-02 03:50:37,275 - INFO - Starting analysis for: data/HyperVC.pdf
# 2025-11-02 03:50:39,409 - INFO - ✅ Analysis completed successfully.
# 📊 Pitch Deck Evaluation Results
# ----------------------------------------
# From raw:------
# Here are the scores for each metric:
#
# 1. Team Experience and track record: 6/10
# Reason: The team has some relevant experience in business consultancy, B2B SaaS, and AI, but it's not extensive, and there's no clear VC or investment experience.
#
# 2. Market Size: 9/10
# Reason: The total addressable market (TAM) is estimated to be $1.025 billion, which is substantial, and the market size is well-researched and supported by credible sources.
#
# 3. Problem-Solution Fit: 8/10
# Reason: The problem of manual and time-consuming screening processes for VCs is well-articulated, and the solution of an AI-powered platform for instant screening and evaluation is a good fit.
#
# 4. Product Market Fit: 7/10
# Reason: While the solution is a good fit for the problem, there's limited evidence of product-market fit, as the pilot has not yet been launched, and there's no clear validation of the product's effectiveness.
#
# 5. Competitive Landscape: 8/10
# Reason: The competitive landscape is acknowledged, and the startup's competitive advantage is clearly articulated, with a focus on real-time evolution and firm-specific learning.
#
# 6. Traction (If not Pre-seed): 2/10
# Reason: As the startup is pre-seed, there's no traction yet, and the pilot has not been launched, so there's limited evidence of customer interest or adoption.
#
# 7. Business Model: 9/10
# Reason: The business model is clear and well-articulated, with a B2B SaaS subscription-based approach and a clear average contract value of $25,000/year.
#
# 8. Financial Projections: 8/10
# Reason: The financial projections are detailed and well-structured, with clear revenue and profit projections, but the assumptions around churn rates and growth may be optimistic.
#
# 9. GTM Strategy: 8/10
# Reason: The go-to-market strategy is clear, with a phased approach to launching the pilot, onboarding VC firms, and expanding sales efforts, but it may be challenging to execute.
#
# 10. Scalability: 9/10
# Reason: The solution has the potential to scale, with a focus on automation and AI-powered evaluation, which can handle large volumes of data and support growth.
#
# Overall Score: 7.5/10
# The startup has a strong value proposition, a large and well-researched market, and a clear business model, but the team's experience and traction are limited, and the financial projections may be optimistic.
#
# Executive Summary: HyperVC.AI is an AI-powered platform that automates and enhances deal screening for VCs, addressing a significant pain point in the industry. With a strong value proposition and a large market, the startup has potential for growth, but needs to execute its go-to-market strategy and validate its product-market fit.
#
# Strengths:
# * Strong value proposition
# * Large and well-researched market
# * Clear business model
# * Competitive advantage
#
# Weaknesses:
# * Limited team experience
# * No traction yet
# * Optimistic financial projections
# * Challenging go-to-market strategy

# %%
from openai import OpenAI
from utils.file_handler import load_config

config = load_config()
client = OpenAI(api_key=config.groq.api_key, base_url=config.groq.base_url)

models = client.models.list()
print([m.id for m in models.data])
# Out:
# ['llama-3.3-70b-versatile', 'moonshotai/kimi-k2-instruct', 'moonshotai/kimi-k2-instruct-0905', 'meta-llama/llama-prompt-guard-2-86m', 'allam-2-7b', 'meta-llama/llama-prompt-guard-2-22m', 'playai-tts-arabic', 'playai-tts', 'meta-llama/llama-guard-4-12b', 'whisper-large-v3', 'openai/gpt-oss-20b', 'whisper-large-v3-turbo', 'groq/compound-mini', 'meta-llama/llama-4-scout-17b-16e-instruct', 'openai/gpt-oss-120b', 'groq/compound', 'llama-3.1-8b-instant', 'meta-llama/llama-4-maverick-17b-128e-instruct', 'qwen/qwen3-32b']

# %%
file_path = "data/TinyTitans.pptx"
pitch_text = extract_text(file_path)
results = analyze_pitch_deck(pitch_text)

print("Pitch Deck Evaluation:")
for metric, score in results.items():
    print(f"{metric}: {score}")
# Out:
# LLM Response:
#  Here is the evaluation of the startup:
#
# Metric Name: Team Experience and track record
# Score: 6/10
# Reason: The team members are responsible caregivers for at least one child under 5 years old, which shows they understand the problem, but there is no clear indication of their relevant business or entrepreneurial experience.
#
# Metric Name: Market Size
# Score: 8/10
# Reason: The market size is estimated to be $2.2 billion using a bottom-up approach, and primary research has been conducted to validate the market size.
#
# Metric Name: Problem-Solution Fit
# Score: 9/10
# Reason: The problem of head injuries in children is clearly articulated, and the solution, a protective and comfortable bucket hat, addresses the problem effectively.
#
# Metric Name: Product Market Fit
# Score: 8/10
# Reason: The product has been tested with positive reactions from potential customers, but more data is needed to confirm product-market fit.
#
# Metric Name: Competitive Landscape
# Score: 7/10
# Reason: The competitive landscape is analyzed, and the product is differentiated from competitors, but the analysis could be more in-depth.
#
# Metric Name: Traction (If not Pre-seed)
# Score: 5/10
# Reason: There is no clear indication of traction, such as revenue or user acquisition, but the company has a goal to sign contracts with baby retailers.
#
# Metric Name: Business Model
# Score: 8/10
# Reason: The business model is clearly outlined, with a goal to reach 2M parents and generate revenue through sales.
#
# Metric Name: Financial Projections
# Score: 7/10
# Reason: The financial projections are provided, with a goal to generate over $1M in revenue by year 3, but more detailed financials would be helpful.
#
# Metric Name: GTM Strategy
# Score: 8/10
# Reason: The go-to-market strategy is outlined, with phases for retail expansion, market testing, and local partnerships.
#
# Metric Name: Scalability
# Score: 8/10
# Reason: The company has the potential to scale faster than a competitor, Safehead, based on financial projections and product-market fit.
#
# Overall Score: 7.5/10
# Reason: The startup has a clear problem-solution fit, a large market size, and a well-outlined business model, but lacks detailed financials and traction.
#
# Executive Summary:
# Tiny Titans is a startup that offers a protective and comfortable bucket hat for children to prevent head injuries. The company has a clear problem-solution fit, a large market size, and a well-outlined business model. With a strong go-to-market strategy and potential for scalability, Tiny Titans has a promising future.
#
# Strengths:
# * Clear problem-solution fit
# * Large market size
# * Well-outlined business model
# * Strong go-to-market strategy
# * Potential for scalability
#
# Weaknesses:
# * Lack of detailed financials
# * Limited traction
# * No clear indication of team's relevant business or entrepreneurial experience
# * Competitive landscape analysis could be more in-depth
# Pitch Deck Evaluation:
# Here is the evaluation of the startup:
# Metric Name: Scalability
# Score: 8
# Reason: The startup has a clear problem-solution fit, a large market size, and a well-outlined business model, but lacks detailed financials and traction.
# Overall Score: 7.5/10
# Executive Summary:
# Strengths:
# Weaknesses:
